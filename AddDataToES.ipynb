# %%
import json
import elasticsearch

# %%
data = json.load(open('./trump3.json'))

# %%
es = elasticsearch.Elasticsearch()

# %%
es.ping()
# Out:
# True

# %%
url = "http://localhost:9200/test/_test"
import requests
r = requests.post(url, json=data)

# %%
for dat in data:
#     dat["counter"] = 0 
#     dat["classifications"] =[]
#     dat['labelers'] =[]
    es.index(index='test',doc_type='test',body=dat)
